# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('googleplaystore(1).csv')

# %%
data
# Out:
#                                                      App             Category
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN  \
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
data.head(5)
# Out:
#                                                  App        Category  Rating
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1  \
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating
# 0     159   19M      10,000+  Free     0       Everyone  \
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver
# 0               Art & Design   January 7, 2018               1.0.0  \
# ...

# %%
data.tail(5)
# Out:
#                                                  App             Category
# 10836                               Sya9a Maroc - FR               FAMILY  \
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price
# 10836     4.5      38                 53M       5,000+  Free     0  \
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver
# ...

# %%
data.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
data.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
data.shape
# Out:
# (10841, 13)

# %%
data.count
# Out:
# <bound method DataFrame.count of                                                      App             Category
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN  \
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
data.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of                                                      App             Category
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN  \
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# ...

# %%
print(data.isnull().sum())
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
data = data.dropna()    
data.count()
# Out:
# App               9360
# Category          9360
# Rating            9360
# Reviews           9360
# Size              9360
# Installs          9360
# Type              9360
# Price             9360
# Content Rating    9360
# Genres            9360
# Last Updated      9360
# Current Ver       9360
# Android Ver       9360
# dtype: int64

# %%
data.head(5)
# Out:
#                                                  App        Category  Rating
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1  \
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating
# 0     159   19M      10,000+  Free     0       Everyone  \
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver
# 0               Art & Design   January 7, 2018               1.0.0  \
# ...

# %%
sns.heatmap(data.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
data.hist(figsize=(30,30))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(x=data['Android Ver'],y= data['Reviews'])
ax.set_xlabel('Size')
ax.set_ylabel('Ratings')
plt.show()

# %%
sns.pairplot(data)

# %%
data.plot(kind='density', figsize=(10,10))
plt.title("Ratings of App")
plt.ylabel('App')
plt.xlabel('Ratings')
# Out:
# Text(0.5, 0, 'Ratings')

# %%
#2-->>
fig, ax = plt.subplots(figsize=(20,6))
ax.scatter(x=data['Installs'],y= data['Rating'])
ax.set_xlabel('Installs')
ax.set_ylabel('Ratings')
plt.show()

# %%
#•	Does a higher size or price necessarily mean that an app would perform better than the other apps?
#no price is not necessarily mean that an app would perform better than the other apps
